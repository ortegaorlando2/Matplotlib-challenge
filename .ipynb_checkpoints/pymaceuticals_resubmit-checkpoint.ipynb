# %% [markdown]
# ## Observations and Insights

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# %%
#count all the rows original in data
rowsn=study_results.count
print(rowsn)
# Out:
# <bound method DataFrame.count of      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites
# 0        b128          0           45.000000                 0
# 1        f932          0           45.000000                 0
# 2        g107          0           45.000000                 0
# 3        a457          0           45.000000                 0
# 4        c819          0           45.000000                 0
# ...       ...        ...                 ...               ...
# 1888     r944         45           41.581521                 2
# 1889     u364         45           31.023923                 3
# 1890     p438         45           61.433892                 1
# 1891     x773         45           58.634971                 4
# 1892     b879         45           72.555239                 2
#
# [1893 rows x 4 columns]>

# %%
# # Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint.
# Optional: Get all the data for the duplicate mouse ID. 
duplicateRowsDF = study_results[study_results.duplicated(['Mouse ID','Timepoint'])]
print("Duplicate Rows :", duplicateRowsDF, sep='\n')
# Out:
# Duplicate Rows :
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites
# 137      g989          0           45.000000                 0
# 360      g989          5           47.570392                 0
# 681      g989         10           49.880528                 0
# 869      g989         15           53.442020                 0
# 1111     g989         20           54.657650                 1

# %%
#cleaning repeated rows in the data
study_results.drop_duplicates(subset=['Mouse ID', 'Timepoint'])

# 5 rows were duplicates in both Mouse ID and Timepoint and were deleted from memory
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites
# 0        b128          0           45.000000                 0
# 1        f932          0           45.000000                 0
# 2        g107          0           45.000000                 0
# 3        a457          0           45.000000                 0
# 4        c819          0           45.000000                 0
# ...       ...        ...                 ...               ...
# 1888     r944         45           41.581521                 2
# 1889     u364         45           31.023923                 3
# 1890     p438         45           61.433892                 1
# 1891     x773         45           58.634971                 4
# 1892     b879         45           72.555239                 2
#
# [1888 rows x 4 columns]

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.

study_resultsnew=(study_results.drop_duplicates(subset=['Mouse ID', 'Timepoint']))

# %%
# Checking the number of mice in the clean DataFrame.
count=study_resultsnew['Mouse ID'].count
print(count)
# Out:
# <bound method Series.count of 0       b128
# 1       f932
# 2       g107
# 3       a457
# 4       c819
#         ...
# 1888    r944
# 1889    u364
# 1890    p438
# 1891    x773
# 1892    b879
# Name: Mouse ID, Length: 1888, dtype: object>

# %%
# Combine the data into a single dataset
MouseData=mouse_metadata.merge(study_resultsnew, how='inner', on='Mouse ID', left_index=False, sort=True)

# %%
# Display the data table for preview
MouseData
# Out:
#      Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 0        a203    Infubinol  Female          20          23          0
# 1        a203    Infubinol  Female          20          23          5
# 2        a203    Infubinol  Female          20          23         10
# 3        a203    Infubinol  Female          20          23         15
# 4        a203    Infubinol  Female          20          23         20
# ...       ...          ...     ...         ...         ...        ...
# 1883     z969     Naftisol    Male           9          30         25
# 1884     z969     Naftisol    Male           9          30         30
# 1885     z969     Naftisol    Male           9          30         35
# 1886     z969     Naftisol    Male           9          30         40
# 1887     z969     Naftisol    Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              48.508468                 0
# 2              51.852437                 1
# 3              52.777870                 1
# 4              55.173336                 1
# ...                  ...               ...
# 1883           63.145652                 2
# 1884           65.841013                 3
# 1885           69.176246                 4
# 1886           70.314904                 4
# 1887           73.867845                 4
#
# [1888 rows x 8 columns]

# %% [markdown]
# ## Summary Statistics

# %%
# drop the Na values and check that all indexes are correct to have an accurate count
TumorVolume_df=MouseData.dropna(subset=['Tumor Volume (mm3)'])
TumorVolume_list=TumorVolume_df['Tumor Volume (mm3)']
TumorVolume_list.reset_index(drop=True,inplace=True)

# %%
#calculate mean
TVmean=TumorVolume_list.mean()
TVmean
# Out:
# 50.449276454131414

# %%
#calculate median
TVmedian=TumorVolume_list.median()
TVmedian
# Out:
# 48.951421075

# %%
#calculate the sum and count first
TVsum=TumorVolume_list.sum()
TVsum
TVcount=TumorVolume_list.count()
TVcount, TVsum, TVsum/TVcount
# Out:
# (1888, 95248.2339454, 50.44927645413136)

# %%
#calculating variance with old fashion method to secure that all elements are fine
Myelement=0
sumMyelementvariance=0
for i in range(TVcount-1):
    Myelementvariance=(float(TumorVolume_list[i])-TVmean)**2
    sumMyelementvariance= sumMyelementvariance + Myelementvariance
    
TVvariance=sumMyelementvariance/TVcount
TVvariance
# Out:
# 78.95879831248787

# %%
#calculates standard deviation using scipy
TVstd=st.stats.tstd(TumorVolume_list, axis=0, ddof=1)

# %%
#calculates sem using scipy
TVsem=st.stats.sem(TumorVolume_list,axis=0, ddof=1)

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume 

TotalTumorVolumestats=pd.DataFrame.from_dict({'index':'Tumor Volume','Count':[TVcount],'Mean':[TVmean],'Median':[TVmedian],'Variance':[TVvariance],
                                    'Stand deviation':TVstd,'SEM':[TVsem]})
TotalTumorVolumestats.style.hide_index()
# Out:
# <style  type="text/css" >
# </style><table id="T_70ce079f_7b0f_11eb_9ac9_e4a7a0f1e64e" ><thead>    <tr>        <th class="col_heading level0 col0" >index</th>        <th class="col_heading level0 col1" >Count</th>        <th class="col_heading level0 col2" >Mean</th>        <th class="col_heading level0 col3" >Median</th>        <th class="col_heading level0 col4" >Variance</th>        <th class="col_heading level0 col5" >Stand deviation</th>        <th class="col_heading level0 col6" >SEM</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_70ce079f_7b0f_11eb_9ac9_e4a7a0f1e64erow0_col0" class="data row0 col0" >Tumor Volume</td>
#                         <td id="T_70ce079f_7b0f_11eb_9ac9_e4a7a0f1e64erow0_col1" class="data row0 col1" >1888</td>
#                         <td id="T_70ce079f_7b0f_11eb_9ac9_e4a7a0f1e64erow0_col2" class="data row0 col2" >50.449276</td>
#                         <td id="T_70ce079f_7b0f_11eb_9ac9_e4a7a0f1e64erow0_col3" class="data row0 col3" >48.951421</td>
#                         <td id="T_70ce079f_7b0f_11eb_9ac9_e4a7a0f1e64erow0_col4" class="data row0 col4" >78.958798</td>
#                         <td id="T_70ce079f_7b0f_11eb_9ac9_e4a7a0f1e64erow0_col5" class="data row0 col5" >8.904565</td>
#                         <td id="T_70ce079f_7b0f_11eb_9ac9_e4a7a0f1e64erow0_col6" class="data row0 col6" >0.204933</td>
#             </tr>
#     </tbody></table>

# %%
# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume. 
# Assemble the resulting series into a single summary dataframe.

# %%
TumorVolume_df
TumorVolume_df=MouseData.dropna(subset=['Tumor Volume (mm3)'])
TumorVolume_df=MouseData.dropna(subset=['Drug Regimen'])
TumorVolume_df
# Out:
#      Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 0        a203    Infubinol  Female          20          23          0
# 1        a203    Infubinol  Female          20          23          5
# 2        a203    Infubinol  Female          20          23         10
# 3        a203    Infubinol  Female          20          23         15
# 4        a203    Infubinol  Female          20          23         20
# ...       ...          ...     ...         ...         ...        ...
# 1883     z969     Naftisol    Male           9          30         25
# 1884     z969     Naftisol    Male           9          30         30
# 1885     z969     Naftisol    Male           9          30         35
# 1886     z969     Naftisol    Male           9          30         40
# 1887     z969     Naftisol    Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              48.508468                 0
# 2              51.852437                 1
# 3              52.777870                 1
# 4              55.173336                 1
# ...                  ...               ...
# 1883           63.145652                 2
# 1884           65.841013                 3
# 1885           69.176246                 4
# 1886           70.314904                 4
# 1887           73.867845                 4
#
# [1888 rows x 8 columns]

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

TumorRegimeVolume_df=TumorVolume_df[['Drug Regimen','Tumor Volume (mm3)']]
TumorRegimeVolume_df
# Out:
#      Drug Regimen  Tumor Volume (mm3)
# 0       Infubinol           45.000000
# 1       Infubinol           48.508468
# 2       Infubinol           51.852437
# 3       Infubinol           52.777870
# 4       Infubinol           55.173336
# ...           ...                 ...
# 1883     Naftisol           63.145652
# 1884     Naftisol           65.841013
# 1885     Naftisol           69.176246
# 1886     Naftisol           70.314904
# 1887     Naftisol           73.867845
#
# [1888 rows x 2 columns]

# %%
# Using the aggregation method, produce the same summary statistics in a single line

# %%
TVstatsRegime=pd.DataFrame(TumorRegimeVolume_df.groupby(['Drug Regimen']).agg(['count','mean','median','var','std','sem'])).reset_index()
TVstatsRegime.style.hide_index()
# Out:
# <style  type="text/css" >
# </style><table id="T_70df2f22_7b0f_11eb_82fc_e4a7a0f1e64e" ><thead>    <tr>        <th class="col_heading level0 col0" >Drug Regimen</th>        <th class="col_heading level0 col1" colspan=6>Tumor Volume (mm3)</th>    </tr>    <tr>        <th class="col_heading level1 col0" ></th>        <th class="col_heading level1 col1" >count</th>        <th class="col_heading level1 col2" >mean</th>        <th class="col_heading level1 col3" >median</th>        <th class="col_heading level1 col4" >var</th>        <th class="col_heading level1 col5" >std</th>        <th class="col_heading level1 col6" >sem</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_70df2f22_7b0f_11eb_82fc_e4a7a0f1e64erow0_col0" class="data row0 col0" >Capomulin</td>
#                         <td id="T_70df2f22_7b0f_11eb_82fc_e4a7a0f1e64erow0_col1" class="data row0 col1" >230</td>
#                         <td id="T_70df2f22_7b0f_11eb_82fc_e4a7a0f1e64erow0_col2" class="data row0 col2" >40.675741</td>
#                         <td id="T_70df2f22_7b0f_11eb_82fc_e4a7a0f1e64erow0_col3" class="data row0 col3" >41.557809</td>
#                         <td id="T_70df2f22_7b0f_11eb_82fc_e4a7a0f1e64erow0_col4" class="data row0 col4" >24.947764</td>
#                         <td id="T_70df2f22_7b0f_11eb_82fc_e4a7a0f1e64erow0_col5" class="data row0 col5" >4.994774</td>
#                         <td id="T_70df2f22_7b0f_11eb_82fc_e4a7a0f1e64erow0_col6" class="data row0 col6" >0.329346</td>
#             </tr>
#             <tr>
#                                 <td id="T_70df2f22_7b0f_11eb_82fc_e4a7a0f1e64erow1_col0" class="data row1 col0" >Ceftamin</td>
#                         <td id="T_70df2f22_7b0f_11eb_82fc_e4a7a0f1e64erow1_col1" class="data row1 col1" >178</td>
#                         <td id="T_70df2f22_7b0f_11eb_82fc_e4a7a0f1e64erow1_col2" class="data row1 col2" >52.591172</td>
#                         <td id="T_70df2f22_7b0f_11eb_82fc_e4a7a0f1e64erow1_col3" class="data row1 col3" >51.776157</td>
#                         <td id="T_70df2f22_7b0f_11eb_82fc_e4a7a0f1e64erow1_col4" class="data row1 col4" >39.290177</td>
#                         <td id="T_70df2f22_7b0f_11eb_82fc_e4a7a0f1e64erow1_col5" class="data row1 col5" >6.268188</td>
#                         <td id="T_70df2f22_7b0f_11eb_82fc_e4a7a0f1e64erow1_col6" class="data row1 col6" >0.469821</td>
#             </tr>
#             <tr>
#                                 <td id="T_70df2f22_7b0f_11eb_82fc_e4a7a0f1e64erow2_col0" class="data row2 col0" >Infubinol</td>
#                         <td id="T_70df2f22_7b0f_11eb_82fc_e4a7a0f1e64erow2_col1" class="data row2 col1" >178</td>
#                         <td id="T_70df2f22_7b0f_11eb_82fc_e4a7a0f1e64erow2_col2" class="data row2 col2" >52.884795</td>
#                         <td id="T_70df2f22_7b0f_11eb_82fc_e4a7a0f1e64erow2_col3" class="data row2 col3" >51.820584</td>
#                         <td id="T_70df2f22_7b0f_11eb_82fc_e4a7a0f1e64erow2_col4" class="data row2 col4" >43.128684</td>
#                         <td id="T_70df2f22_7b0f_11eb_82fc_e4a7a0f1e64erow2_col5" class="data row2 col5" >6.567243</td>
#                         <td id="T_70df2f22_7b0f_11eb_82fc_e4a7a0f1e64erow2_col6" class="data row2 col6" >0.492236</td>
#             </tr>
#             <tr>
#                                 <td id="T_70df2f22_7b0f_11eb_82fc_e4a7a0f1e64erow3_col0" class="data row3 col0" >Ketapril</td>
#                         <td id="T_70df2f22_7b0f_11eb_82fc_e4a7a0f1e64erow3_col1" class="data row3 col1" >188</td>
#                         <td id="T_70df2f22_7b0f_11eb_82fc_e4a7a0f1e64erow3_col2" class="data row3 col2" >55.235638</td>
#                         <td id="T_70df2f22_7b0f_11eb_82fc_e4a7a0f1e64erow3_col3" class="data row3 col3" >53.698743</td>
#                         <td id="T_70df2f22_7b0f_11eb_82fc_e4a7a0f1e64erow3_col4" class="data row3 col4" >68.553577</td>
#                         <td id="T_70df2f22_7b0f_11eb_82fc_e4a7a0f1e64erow3_col5" class="data row3 col5" >8.279709</td>
#                         <td id="T_70df2f22_7b0f_11eb_82fc_e4a7a0f1e64erow3_col6" class="data row3 col6" >0.603860</td>
#             </tr>
#             <tr>
#                                 <td id="T_70df2f22_7b0f_11eb_82fc_e4a7a0f1e64erow4_col0" class="data row4 col0" >Naftisol</td>
#                         <td id="T_70df2f22_7b0f_11eb_82fc_e4a7a0f1e64erow4_col1" class="data row4 col1" >186</td>
#                         <td id="T_70df2f22_7b0f_11eb_82fc_e4a7a0f1e64erow4_col2" class="data row4 col2" >54.331565</td>
#                         <td id="T_70df2f22_7b0f_11eb_82fc_e4a7a0f1e64erow4_col3" class="data row4 col3" >52.509285</td>
#                         <td id="T_70df2f22_7b0f_11eb_82fc_e4a7a0f1e64erow4_col4" class="data row4 col4" >66.173479</td>
#                         <td id="T_70df2f22_7b0f_11eb_82fc_e4a7a0f1e64erow4_col5" class="data row4 col5" >8.134708</td>
#                         <td id="T_70df2f22_7b0f_11eb_82fc_e4a7a0f1e64erow4_col6" class="data row4 col6" >0.596466</td>
#             </tr>
#             <tr>
#                                 <td id="T_70df2f22_7b0f_11eb_82fc_e4a7a0f1e64erow5_col0" class="data row5 col0" >Placebo</td>
#                         <td id="T_70df2f22_7b0f_11eb_82fc_e4a7a0f1e64erow5_col1" class="data row5 col1" >181</td>
#                         <td id="T_70df2f22_7b0f_11eb_82fc_e4a7a0f1e64erow5_col2" class="data row5 col2" >54.033581</td>
#                         <td id="T_70df2f22_7b0f_11eb_82fc_e4a7a0f1e64erow5_col3" class="data row5 col3" >52.288934</td>
#                         <td id="T_70df2f22_7b0f_11eb_82fc_e4a7a0f1e64erow5_col4" class="data row5 col4" >61.168083</td>
#                         <td id="T_70df2f22_7b0f_11eb_82fc_e4a7a0f1e64erow5_col5" class="data row5 col5" >7.821003</td>
#                         <td id="T_70df2f22_7b0f_11eb_82fc_e4a7a0f1e64erow5_col6" class="data row5 col6" >0.581331</td>
#             </tr>
#             <tr>
#                                 <td id="T_70df2f22_7b0f_11eb_82fc_e4a7a0f1e64erow6_col0" class="data row6 col0" >Propriva</td>
#                         <td id="T_70df2f22_7b0f_11eb_82fc_e4a7a0f1e64erow6_col1" class="data row6 col1" >156</td>
#                         <td id="T_70df2f22_7b0f_11eb_82fc_e4a7a0f1e64erow6_col2" class="data row6 col2" >52.393463</td>
#                         <td id="T_70df2f22_7b0f_11eb_82fc_e4a7a0f1e64erow6_col3" class="data row6 col3" >50.909965</td>
#                         <td id="T_70df2f22_7b0f_11eb_82fc_e4a7a0f1e64erow6_col4" class="data row6 col4" >43.138803</td>
#                         <td id="T_70df2f22_7b0f_11eb_82fc_e4a7a0f1e64erow6_col5" class="data row6 col5" >6.568014</td>
#                         <td id="T_70df2f22_7b0f_11eb_82fc_e4a7a0f1e64erow6_col6" class="data row6 col6" >0.525862</td>
#             </tr>
#             <tr>
#                                 <td id="T_70df2f22_7b0f_11eb_82fc_e4a7a0f1e64erow7_col0" class="data row7 col0" >Ramicane</td>
#                         <td id="T_70df2f22_7b0f_11eb_82fc_e4a7a0f1e64erow7_col1" class="data row7 col1" >228</td>
#                         <td id="T_70df2f22_7b0f_11eb_82fc_e4a7a0f1e64erow7_col2" class="data row7 col2" >40.216745</td>
#                         <td id="T_70df2f22_7b0f_11eb_82fc_e4a7a0f1e64erow7_col3" class="data row7 col3" >40.673236</td>
#                         <td id="T_70df2f22_7b0f_11eb_82fc_e4a7a0f1e64erow7_col4" class="data row7 col4" >23.486704</td>
#                         <td id="T_70df2f22_7b0f_11eb_82fc_e4a7a0f1e64erow7_col5" class="data row7 col5" >4.846308</td>
#                         <td id="T_70df2f22_7b0f_11eb_82fc_e4a7a0f1e64erow7_col6" class="data row7 col6" >0.320955</td>
#             </tr>
#             <tr>
#                                 <td id="T_70df2f22_7b0f_11eb_82fc_e4a7a0f1e64erow8_col0" class="data row8 col0" >Stelasyn</td>
#                         <td id="T_70df2f22_7b0f_11eb_82fc_e4a7a0f1e64erow8_col1" class="data row8 col1" >181</td>
#                         <td id="T_70df2f22_7b0f_11eb_82fc_e4a7a0f1e64erow8_col2" class="d

# %% [markdown]
# ## Bar and Pie Charts

# %%
#let's check the column names with enumerate
col_mapping = [f"{c[0]}:{c[1]}" for c in enumerate(TVstatsRegime.columns)]
col_mapping
# Out:
# ["0:('Drug Regimen', '')",
#  "1:('Tumor Volume (mm3)', 'count')",
#  "2:('Tumor Volume (mm3)', 'mean')",
#  "3:('Tumor Volume (mm3)', 'median')",
#  "4:('Tumor Volume (mm3)', 'var')",
#  "5:('Tumor Volume (mm3)', 'std')",
#  "6:('Tumor Volume (mm3)', 'sem')"]

# %%
# Generate a bar plot showing the total number of measurements taken on each drug regimen using pandas.

TVstatsRegime=TVstatsRegime.loc[:,[('Drug Regimen', ''),('Tumor Volume (mm3)', 'count')]]
TVstatsRegime
# Out:
#   Drug Regimen Tumor Volume (mm3)
#                             count
# 0    Capomulin                230
# 1     Ceftamin                178
# 2    Infubinol                178
# 3     Ketapril                188
# 4     Naftisol                186
# 5      Placebo                181
# 6     Propriva                156
# 7     Ramicane                228
# 8     Stelasyn                181
# 9    Zoniferol                182

# %%
#Tumor Volume measurements per Regimen barplot
TVstatsRegime.plot(kind='bar', x=('Drug Regimen', ''), y=('Tumor Volume (mm3)', 'count'), rot=90, legend=False)

# %%
# Generate a bar plot showing the total number of measurements taken on each drug regimen using pyplot.
# %matplotlib inline
plt.style.use('ggplot')

x = TVstatsRegime[('Drug Regimen', '')]
count = TVstatsRegime[('Tumor Volume (mm3)', 'count')]

plt.bar(x, count, color='green')
plt.xlabel("Drug Regimen")
plt.ylabel("count")
plt.title("Number of Measurements per Drug Regime")

plt.xticks(x, rotation=90)

plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pandas
MouseData
# Out:
#      Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 0        a203    Infubinol  Female          20          23          0
# 1        a203    Infubinol  Female          20          23          5
# 2        a203    Infubinol  Female          20          23         10
# 3        a203    Infubinol  Female          20          23         15
# 4        a203    Infubinol  Female          20          23         20
# ...       ...          ...     ...         ...         ...        ...
# 1883     z969     Naftisol    Male           9          30         25
# 1884     z969     Naftisol    Male           9          30         30
# 1885     z969     Naftisol    Male           9          30         35
# 1886     z969     Naftisol    Male           9          30         40
# 1887     z969     Naftisol    Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              48.508468                 0
# 2              51.852437                 1
# 3              52.777870                 1
# 4              55.173336                 1
# ...                  ...               ...
# 1883           63.145652                 2
# 1884           65.841013                 3
# 1885           69.176246                 4
# 1886           70.314904                 4
# 1887           73.867845                 4
#
# [1888 rows x 8 columns]

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
Sex_df=MouseData.groupby(['Sex']).count()
Sex_df['Mouse ID']
# Out:
# Sex
# Female    930
# Male      958
# Name: Mouse ID, dtype: int64

# %%
labels = ['Male', 'Female']
sizes = [Sex_df['Mouse ID'][0],Sex_df['Mouse ID'][1]]

#add colors
colors = ['#ff9999','#66b3ff']
fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%',
        shadow=True, startangle=90)
# Equal aspect ratio ensures that pie is drawn as a circle
ax1.axis('equal')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
Regimen_df=MouseData.set_index('Drug Regimen')
Regimen_df
# Out:
#              Mouse ID     Sex  Age_months  Weight (g)  Timepoint  \
# Drug Regimen
# Infubinol        a203  Female          20          23          0
# Infubinol        a203  Female          20          23          5
# Infubinol        a203  Female          20          23         10
# Infubinol        a203  Female          20          23         15
# Infubinol        a203  Female          20          23         20
# ...               ...     ...         ...         ...        ...
# Naftisol         z969    Male           9          30         25
# Naftisol         z969    Male           9          30         30
# Naftisol         z969    Male           9          30         35
# Naftisol         z969    Male           9          30         40
# Naftisol         z969    Male           9          30         45
#
#               Tumor Volume (mm3)  Metastatic Sites
# Drug Regimen
# Infubinol              45.000000                 0
# Infubinol              48.508468                 0
# Infubinol              51.852437                 1
# Infubinol              52.777870                 1
# Infubinol              55.173336                 1
# ...                          ...               ...
# Naftisol               63.145652                 2
# Naftisol               65.841013                 3
# Naftisol               69.176246                 4
# Naftisol               70.314904                 4
# Naftisol               73.867845                 4
#
# [1888 rows x 7 columns]

# %%
#Regimen_df=MouseData[['Capomulin']]
Capomulin_df=Regimen_df.loc[['Capomulin']].reset_index()
Ramicane_df=Regimen_df.loc[['Ramicane']].reset_index()
Infubinol_df=Regimen_df.loc[['Infubinol']].reset_index() 
Ceftamin_df=Regimen_df.loc[['Ceftamin']].reset_index()

Capomulin_df
# Out:
#     Drug Regimen Mouse ID     Sex  Age_months  Weight (g)  Timepoint  \
# 0      Capomulin     b128  Female           9          22          0
# 1      Capomulin     b128  Female           9          22          5
# 2      Capomulin     b128  Female           9          22         10
# 3      Capomulin     b128  Female           9          22         15
# 4      Capomulin     b128  Female           9          22         20
# ..           ...      ...     ...         ...         ...        ...
# 225    Capomulin     y793    Male          17          17         25
# 226    Capomulin     y793    Male          17          17         30
# 227    Capomulin     y793    Male          17          17         35
# 228    Capomulin     y793    Male          17          17         40
# 229    Capomulin     y793    Male          17          17         45
#
#      Tumor Volume (mm3)  Metastatic Sites
# 0             45.000000                 0
# 1             45.651331                 0
# 2             43.270852                 0
# 3             43.784893                 0
# 4             42.731552                 0
# ..                  ...               ...
# 225           38.992734                 2
# 226           35.726023                 2
# 227           36.327870                 2
# 228           31.475411                 2
# 229           31.896238                 2
#
# [230 rows x 8 columns]

# %%
# Start by getting the last (greatest) timepoint for each mouse

c_to_keep=['Drug Regimen','Mouse ID','Tumor Volume (mm3)']
Capomulin=Capomulin_df.drop_duplicates(subset=['Mouse ID'], keep='last', inplace=False, ignore_index=False).reset_index()
Capomulin
# Out:
#     index Drug Regimen Mouse ID     Sex  Age_months  Weight (g)  Timepoint  \
# 0       9    Capomulin     b128  Female           9          22         45
# 1      19    Capomulin     b742    Male           7          21         45
# 2      24    Capomulin     f966    Male          16          17         20
# 3      34    Capomulin     g288    Male           3          19         45
# 4      44    Capomulin     g316  Female          22          22         45
# 5      54    Capomulin     i557  Female           1          24         45
# 6      64    Capomulin     i738  Female          23          20         45
# 7      74    Capomulin     j119  Female           7          23         45
# 8      82    Capomulin     j246  Female          21          21         35
# 9      92    Capomulin     l509    Male          17          21         45
# 10    102    Capomulin     l897    Male          17          19         45
# 11    112    Capomulin     m601    Male          22          17         45
# 12    122    Capomulin     m957  Female           3          19         45
# 13    126    Capomulin     r157    Male          22          25         15
# 14    136    Capomulin     r554  Female           8          17         45
# 15    146    Capomulin     r944    Male          12          25         45
# 16    156    Capomulin     s185  Female           3          17         45
# 17    166    Capomulin     s710  Female           1          23         45
# 18    176    Capomulin     t565  Female          20          17         45
# 19    186    Capomulin     u364    Male          18          17         45
# 20    196    Capomulin     v923  Female          19          21         45
# 21    199    Capomulin     w150    Male          23          23         10
# 22    209    Capomulin     w914    Male          24          21         45
# 23    219    Capomulin     x401  Female          16          15         45
# 24    229    Capomulin     y793    Male          17          17         45
#
#     Tumor Volume (mm3)  Metastatic Sites
# 0            38.982878                 2
# 1            38.939633                 0
# 2            30.485985                 0
# 3            37.074024                 1
# 4            40.159220                 2
# 5            47.685963                 1
# 6            37.311846                 2
# 7            38.125164                 1
# 8            38.753265                 1
# 9            41.483008                 3
# 10           38.846876                 1
# 11           28.430964                 1
# 12           33.329098                 1
# 13           46.539206                 0
# 14           32.377357                 3
# 15           41.581521                 2
# 16           23.343598                 1
# 17           40.728578                 1
# 18           34.455298                 0
# 19           31.023923                 3
# 20           40.658124                 2
# 21           39.952347                 0
# 22           36.041047                 2
# 23           28.484033                 0
# 24           31.896238                 2

# %%
#getting last timepoint for the other treatments
Ramicane=Ramicane_df.drop_duplicates(subset=['Mouse ID'], keep='last', inplace=False, ignore_index=False)
Infubinol=Infubinol_df.drop_duplicates(subset=['Mouse ID'], keep='last', inplace=False, ignore_index=False)
Ceftamin=Ceftamin_df.drop_duplicates(subset=['Mouse ID'], keep='last', inplace=False, ignore_index=False)

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:
# Capomulin, Ramicane, Infubinol, and Ceftamin
Capomulin=Capomulin.loc[:,c_to_keep]
Ramicane=Ramicane.loc[:,c_to_keep]
Infubinol=Infubinol.loc[:,c_to_keep]
Ceftamin=Ceftamin.loc[:,c_to_keep]
Capomulin
# Out:
#    Drug Regimen Mouse ID  Tumor Volume (mm3)
# 0     Capomulin     b128           38.982878
# 1     Capomulin     b742           38.939633
# 2     Capomulin     f966           30.485985
# 3     Capomulin     g288           37.074024
# 4     Capomulin     g316           40.159220
# 5     Capomulin     i557           47.685963
# 6     Capomulin     i738           37.311846
# 7     Capomulin     j119           38.125164
# 8     Capomulin     j246           38.753265
# 9     Capomulin     l509           41.483008
# 10    Capomulin     l897           38.846876
# 11    Capomulin     m601           28.430964
# 12    Capomulin     m957           33.329098
# 13    Capomulin     r157           46.539206
# 14    Capomulin     r554           32.377357
# 15    Capomulin     r944           41.581521
# 16    Capomulin     s185           23.343598
# 17    Capomulin     s710           40.728578
# 18    Capomulin     t565           34.455298
# 19    Capomulin     u364           31.023923
# 20    Capomulin     v923           40.658124
# 21    Capomulin     w150           39.952347
# 22    Capomulin     w914           36.041047
# 23    Capomulin     x401           28.484033
# 24    Capomulin     y793           31.896238

# %%
# Merge this group df with the original dataframe to get the tumor volume at the last timepoint
Selected = [Capomulin, Ramicane, Infubinol,Ceftamin]
TumorVolume_Selected = pd.concat(Selected)

# %%
TumorVolume_Selected.set_index('Mouse ID')
# Out:
#          Drug Regimen  Tumor Volume (mm3)
# Mouse ID
# b128        Capomulin           38.982878
# b742        Capomulin           38.939633
# f966        Capomulin           30.485985
# g288        Capomulin           37.074024
# g316        Capomulin           40.159220
# ...               ...                 ...
# x226         Ceftamin           45.000000
# x581         Ceftamin           64.634949
# x822         Ceftamin           61.386660
# y769         Ceftamin           68.594745
# y865         Ceftamin           64.729837
#
# [100 rows x 2 columns]

# %%
# Put treatments into a list for for loop (and later for plot labels)
TumorVolume_Selected.reset_index(drop=True)
Treatments = ['Capomulin', 'Ramicane', 'Infubinol','Ceftamin']
df=TumorVolume_Selected
df
# Out:
#     Drug Regimen Mouse ID  Tumor Volume (mm3)
# 0      Capomulin     b128           38.982878
# 1      Capomulin     b742           38.939633
# 2      Capomulin     f966           30.485985
# 3      Capomulin     g288           37.074024
# 4      Capomulin     g316           40.159220
# ..           ...      ...                 ...
# 137     Ceftamin     x226           45.000000
# 147     Ceftamin     x581           64.634949
# 157     Ceftamin     x822           61.386660
# 167     Ceftamin     y769           68.594745
# 177     Ceftamin     y865           64.729837
#
# [100 rows x 3 columns]

# %%
TumorVolume_Selected
# Out:
#     Drug Regimen Mouse ID  Tumor Volume (mm3)
# 0      Capomulin     b128           38.982878
# 1      Capomulin     b742           38.939633
# 2      Capomulin     f966           30.485985
# 3      Capomulin     g288           37.074024
# 4      Capomulin     g316           40.159220
# ..           ...      ...                 ...
# 137     Ceftamin     x226           45.000000
# 147     Ceftamin     x581           64.634949
# 157     Ceftamin     x822           61.386660
# 167     Ceftamin     y769           68.594745
# 177     Ceftamin     y865           64.729837
#
# [100 rows x 3 columns]

# %%
# Create empty list to fill with tumor vol data (for plotting)
TumorVolume=[]
CapomulinTV=[]
RamicaneTV=[]
InfubinolTV=[]
CeftalinTV=[]

# %%
# Calculate the IQR and quantitatively determine if there are any potential outliers.

# %%
start=0
end=0
    
for i in range(4):
    Treatment=Treatments[i]
    
    start=i*25
    end=(i+1)*25
    b=df.iloc[start:end,2]
    print(f'data range {start}-{end}')
    
    for j in range(0,25):
        a=b.iloc[j]
        lower=b.mean()-1.5*(b.quantile(0.75)-b.quantile(0.25))
        upper=b.mean()+1.5*(b.quantile(0.75)-b.quantile(0.25))
        #print(j)
        if a<lower or a>upper:
            print(f'POSSIBLE outlier in {Treatment} row {j+start},  lowerQ {lower} upperQ {upper} TumorVolume = {a} ')
            
     # Locate the rows which contain mice on each drug and get the tumor volumes
# Out:
# data range 0-25
# POSSIBLE outlier in Capomulin row 16,  lowerQ 24.994772529199995 upperQ 48.34036290920001 TumorVolume = 23.34359787
# data range 25-50
# POSSIBLE outlier in Ramicane row 38,  lowerQ 22.5435853484 upperQ 49.839195508399996 TumorVolume = 22.05012627
# data range 50-75
# POSSIBLE outlier in Infubinol row 55,  lowerQ 40.96254304519999 upperQ 75.3939485252 TumorVolume = 36.321345799999996
# data range 75-100

# %%
# add subset 
 
TumorVolume =TumorVolume_Selected['Tumor Volume (mm3)'].tolist() 
CapomulinTV=TumorVolume[0:24:]
RamicaneTV=TumorVolume[25:49:]
InfubinolTV=TumorVolume[50:74:]
CeftaminTV=TumorVolume[75:99:]

# %%
TumorVolumeTreatments=[CapomulinTV,RamicaneTV,InfubinolTV,CeftaminTV]

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest
import numpy as np

fig, ax = plt.subplots()
bplot=bp = ax.boxplot([CapomulinTV,RamicaneTV,InfubinolTV,CeftaminTV], 1, 
                      sym='k+', labels=["Capomulin","Ramicane","Infubinol", "Ceftamin"], 
                      patch_artist=True)

ax.set_xlabel('Treatment')
ax.set_ylabel('tumor volume %')
plt.setp(bp['boxes'], color='black')
plt.setp(bp['whiskers'], color='r', linestyle='-')
plt.setp(bp['fliers'],  color='red', marker='o' ,markersize=26.0)
ax.yaxis.grid(False)
ax.xaxis.grid(False)

# fill with colors
colors = ['pink', 'lightblue', 'lightgreen',"green"]
for patch, color in zip(bplot['boxes'], colors):
    patch.set_facecolor(color)

plt.show()
#

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a mouse treated 
#with Capomulin

Capomulin_df
# Out:
#     Drug Regimen Mouse ID     Sex  Age_months  Weight (g)  Timepoint  \
# 0      Capomulin     b128  Female           9          22          0
# 1      Capomulin     b128  Female           9          22          5
# 2      Capomulin     b128  Female           9          22         10
# 3      Capomulin     b128  Female           9          22         15
# 4      Capomulin     b128  Female           9          22         20
# ..           ...      ...     ...         ...         ...        ...
# 225    Capomulin     y793    Male          17          17         25
# 226    Capomulin     y793    Male          17          17         30
# 227    Capomulin     y793    Male          17          17         35
# 228    Capomulin     y793    Male          17          17         40
# 229    Capomulin     y793    Male          17          17         45
#
#      Tumor Volume (mm3)  Metastatic Sites
# 0             45.000000                 0
# 1             45.651331                 0
# 2             43.270852                 0
# 3             43.784893                 0
# 4             42.731552                 0
# ..                  ...               ...
# 225           38.992734                 2
# 226           35.726023                 2
# 227           36.327870                 2
# 228           31.475411                 2
# 229           31.896238                 2
#
# [230 rows x 8 columns]

# %%
LineMouse=Capomulin_df[['Mouse ID','Timepoint','Tumor Volume (mm3)']].dropna()
CountMice=pd.DataFrame(LineMouse.groupby(["Mouse ID"][0]).count())
CountMice
# Out:
#           Timepoint  Tumor Volume (mm3)
# Mouse ID
# b128             10                  10
# b742             10                  10
# f966              5                   5
# g288             10                  10
# g316             10                  10
# i557             10                  10
# i738             10                  10
# j119             10                  10
# j246              8                   8
# l509             10                  10
# l897             10                  10
# m601             10                  10
# m957             10                  10
# r157              4                   4
# r554             10                  10
# r944             10                  10
# s185             10                  10
# s710             10                  10
# t565             10                  10
# u364             10                  10
# v923             10                  10
# w150              3                   3
# w914             10                  10
# x401             10                  10
# y793             10                  10

# %%
OneMouse=LineMouse.loc[LineMouse['Mouse ID']=='i557']
x1=OneMouse['Timepoint'].tolist()
y1=OneMouse['Tumor Volume (mm3)'].tolist()
OneMouse=LineMouse.loc[LineMouse['Mouse ID']=='r944']
x2=OneMouse['Timepoint'].tolist()
y2=OneMouse['Timepoint'].tolist()

# %%
#Line plot
fig, ax = plt.subplots()

# Using set_dashes() to modify dashing of an existing line
line1=ax.plot(x1, y1, label='Mouse i557',)
line2=ax.plot(x2, y2, label='Mouse r944', color='blue')


ax.legend()
plt.show()

# %%
# Generate a scatter plot of average tumor volume vs. mouse weight for the Capomulin regimen
import statistics
MouseWeight=Capomulin_df[["Tumor Volume (mm3)","Weight (g)"]]
x3=MouseWeight['Weight (g)'].tolist()
y3=MouseWeight['Tumor Volume (mm3)'].tolist()
meanx3=statistics.mean(x3)
stdx3=statistics.pstdev(x3)
meany3=statistics.mean(x3)
stdy3=statistics.pstdev(y3)

# %%
import matplotlib.colors as mcolors
# Plot...

fig, ax = plt.subplots()
plt.scatter(x3, y3, c=y3, cmap="RdYlGn", s=500, edgecolors="black")

ax.set_xlabel('Weight')
ax.set_ylabel('tumor volume %')
# Out:
# Text(0, 0.5, 'tumor volume %')

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen
import scipy
z=Capomulin_df[['Age_months']]
nCapomulin=Capomulin.count()

# %%
scipy.stats.pearsonr(x3,y3)
# Out:
# (0.525699555207717, 9.605446629502006e-18)

# %%
# Linear - Line of best fit
m,b = np.polyfit(x3,y3,1)
print(m,b)
# Out:
# 0.9609669432428354 21.489827213299556

# %%
x5=np.array(x3)
y4=m*x5+b
fig, ax = plt.subplots()
plt.scatter(x5, y3, c=y3, cmap="RdYlGn", s=500, edgecolors="black")

ax.set_xlabel('Weight')
ax.set_ylabel('tumor volume %')

plt.plot(x5, y4,'-')


ax.text(0.95, 0.01, '0.96*x+21.48, r=0.96',
        verticalalignment='bottom', horizontalalignment='right',
        transform=ax.transAxes,
        color='green', fontsize=15)

# (0.5, 0.5, 'matplotlib', horizontalalignment='center',
#     verticalalignment='center', transform=ax.transAxes)

plt.show()
